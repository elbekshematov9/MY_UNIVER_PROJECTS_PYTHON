# %% [markdown]
# <a href="https://colab.research.google.com/github/elbekshematov9/MY_UNIVER_PROJECTS_PYTHON/blob/main/%D0%94%D0%BE%D0%B1%D1%80%D0%BE_%D0%BF%D0%BE%D0%B6%D0%B0%D0%BB%D0%BE%D0%B2%D0%B0%D1%82%D1%8C_%D0%B2_Colab!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=int(input("Enter your age:  "))
high=int(input("Enter your height:  "))

if age+high>=180:
  print("You are adult!")
elif age+high<=150:
  print("You are KID!")
# Out:
# Enter your age:  18
# Enter your height:  130
# You are KID!

# %%
day=input("Week day is: ")
match day:
  case "Monday" | "monday" | "mon":
    print("Today is Monday")
  case "Tuesday" | "tuesday":
    print("Today is Tuesday")
  case "Wednesday":
    print("Today is Wednesday")
  case "Thursday":
    print("Today is Thursday")
  case "Friday":
    print("Today is Friday")
  case "Saturday":
    print("Today is Saturday")
  case "Sunday":
    print("Today is Sunday")
  case _:
    print("Invalid day")
# Out:
# Week day is: mon
# Today is Monday

# %%
for i in range(7):
  # The inner loop controls the columns (from 0 to 8)
  for j in range(9):
    # If we are in the first 3 rows (i < 3) and not in the middle column (j != 4)
    if i < 3 and j != 4:
      print("*", end="")
    # If we are in the subsequent rows (i > 2) and j is in specific columns [2, 3, 5, 6]
    elif i > 2 and j in [2, 3, 5, 6]:
      print("*", end="")
    # If the conditions above are not met, print a space
    else:
      print(" ", end="")
  print()
# Out:
# **** ****
# **** ****
# **** ****
#   ** **
#   ** **
#   ** **
#   ** **

# %%
# Number of levels for the Christmas tree
num = 3

# First Level of Leaves
for i in range(1, num + 1):
    # Print spaces to center the stars
    print(" " * (2 * num - i + 3), end="")
    # Print stars with a space in between
    for j in range(1, i + 1):
        print("*", end=" ")
    # Move to the next line after printing stars
    print()

# Second Level of Leaves
for i in range(1, num + 3):
    print(" " * (2 * num - i + 1), end="")
    for j in range(-1, i + 1):
        print("*", end=" ")
    print()

# Third Level of Leaves (Optional for larger trees)
for i in range(1, num + 5):
    print(" " * (2 * num - i), end="")
    for j in range(-2, i + 1):
        print("*", end=" ")
    print()

# Trunk of the Tree
for i in range(1, num + 3):
    # Print spaces to center the trunk
    print(" " * (2 * num), end="")
    # Print the trunk (3 stars)
    print("* " * 3)
# Out:
#         *
#        * *
#       * * *
#       * * *
#      * * * *
#     * * * * *
#    * * * * * *
#   * * * * * * *
#      * * * *
#     * * * * *
#    * * * * * *
#   * * * * * * *
#  * * * * * * * *
# * * * * * * * * *
# * * * * * * * * * *
#       * * *
#       * * *
#       * * *
#       * * *
#       * * *
